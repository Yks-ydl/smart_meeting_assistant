# %%
import torch

# %%
print("PyTorch版本:", torch.__version__)
# Out:
# PyTorch版本: 2.9.0+cu130

# %%
print("PyTorch编译使用的CUDA版本:", torch.version.cuda)
# Out:
# PyTorch编译使用的CUDA版本: 13.0

# %%
print("是否可用CUDA:", torch.cuda.is_available())
# Out:
# 是否可用CUDA: False
# c:\Users\22575\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\cuda\__init__.py:182: UserWarning: cudaGetDeviceCount() returned cudaErrorNotSupported, likely using older driver or on CPU machine (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\c10\cuda\CUDAFunctions.cpp:88.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
print("当前GPU:", torch.cuda.get_device_name(0))
# Out:
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
